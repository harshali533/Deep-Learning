# %% [markdown]
# Comparison of RNN, LSTM and GRU.

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, SimpleRNN, LSTM, GRU, Dense
from tensorflow.keras.preprocessing.sequence import pad_sequences
import matplotlib.pyplot as plt

# %%
vocab_size = 10000

(x_train, y_train), (x_test, y_test) = tf.keras.datasets.imdb.load_data(num_words=vocab_size)

print("Train size:", len(x_train))
print("Test size:", len(x_test))
# Out:
# Train size: 25000
# Test size: 25000

# %%
max_length = 200

x_train = pad_sequences(x_train, maxlen=max_length)
x_test = pad_sequences(x_test, maxlen=max_length)

# %%
rnn_model = Sequential([
    Embedding(vocab_size, 128, input_length=max_length),
    SimpleRNN(64),
    Dense(1, activation='sigmoid')
])

rnn_model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/embedding.py:100: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(

# %%
lstm_model = Sequential([
    Embedding(vocab_size, 128, input_length=max_length),
    LSTM(64),
    Dense(1, activation='sigmoid')
])

lstm_model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# %%
gru_model = Sequential([
    Embedding(vocab_size, 128, input_length=max_length),
    GRU(64),
    Dense(1, activation='sigmoid')
])

gru_model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# %%
print("\nTraining RNN...")
history_rnn = rnn_model.fit(
    x_train, y_train,
    epochs=3,
    batch_size=64,
    validation_data=(x_test, y_test)
)
# Out:
# Training RNN...
# Epoch 1/3
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 45s 110ms/step - accuracy: 0.7109 - loss: 0.5506 - val_accuracy: 0.5512 - val_loss: 0.8452
# Epoch 2/3
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 80s 105ms/step - accuracy: 0.8132 - loss: 0.4140 - val_accuracy: 0.7686 - val_loss: 0.4991
# Epoch 3/3
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 43s 111ms/step - accuracy: 0.8885 - loss: 0.2724 - val_accuracy: 0.6296 - val_loss: 0.7785

# %%
print("\nTraining LSTM...")
history_lstm = lstm_model.fit(
    x_train, y_train,
    epochs=3,
    batch_size=64,
    validation_data=(x_test, y_test)
)
# Out:
# Training LSTM...
# Epoch 1/3
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 126s 315ms/step - accuracy: 0.8061 - loss: 0.4143 - val_accuracy: 0.8672 - val_loss: 0.3232
# Epoch 2/3
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 136s 347ms/step - accuracy: 0.9028 - loss: 0.2474 - val_accuracy: 0.8686 - val_loss: 0.3118
# Epoch 3/3
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 129s 314ms/step - accuracy: 0.9308 - loss: 0.1827 - val_accuracy: 0.8692 - val_loss: 0.3345

# %%
print("\nTraining GRU...")
history_gru = gru_model.fit(
    x_train, y_train,
    epochs=3,
    batch_size=64,
    validation_data=(x_test, y_test)
)
# Out:
# Training GRU...
# Epoch 1/3
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 133s 333ms/step - accuracy: 0.7684 - loss: 0.4668 - val_accuracy: 0.8315 - val_loss: 0.3783
# Epoch 2/3
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 130s 332ms/step - accuracy: 0.8984 - loss: 0.2559 - val_accuracy: 0.8745 - val_loss: 0.3159
# Epoch 3/3
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 128s 328ms/step - accuracy: 0.9328 - loss: 0.1795 - val_accuracy: 0.8648 - val_loss: 0.3353

# %%
rnn_acc = rnn_model.evaluate(x_test, y_test)[1]
lstm_acc = lstm_model.evaluate(x_test, y_test)[1]
gru_acc = gru_model.evaluate(x_test, y_test)[1]

print("\nFinal Accuracy:")
print("RNN :", rnn_acc)
print("LSTM:", lstm_acc)
print("GRU :", gru_acc)
# Out:
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 12s 16ms/step - accuracy: 0.6296 - loss: 0.7785
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 27s 35ms/step - accuracy: 0.8692 - loss: 0.3345
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 25s 32ms/step - accuracy: 0.8648 - loss: 0.3353
#
# Final Accuracy:
# RNN : 0.6295599937438965
# LSTM: 0.8692399859428406
# GRU : 0.8648399710655212

# %%
rnn_acc = rnn_model.evaluate(x_test, y_test)[1]
lstm_acc = lstm_model.evaluate(x_test, y_test)[1]
gru_acc = gru_model.evaluate(x_test, y_test)[1]

print("\nFinal Accuracy:")
print("RNN :", rnn_acc)
print("LSTM:", lstm_acc)
print("GRU :", gru_acc)
# Out:
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 12s 16ms/step - accuracy: 0.6296 - loss: 0.7785
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 27s 35ms/step - accuracy: 0.8692 - loss: 0.3345
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 26s 33ms/step - accuracy: 0.8648 - loss: 0.3353
#
# Final Accuracy:
# RNN : 0.6295599937438965
# LSTM: 0.8692399859428406
# GRU : 0.8648399710655212

# %%
plt.figure()

plt.plot(history_rnn.history['val_accuracy'], label='RNN')
plt.plot(history_lstm.history['val_accuracy'], label='LSTM')
plt.plot(history_gru.history['val_accuracy'], label='GRU')

plt.title("Validation Accuracy Comparison")
plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.legend()
plt.show()

# %%
plt.figure()

plt.plot(history_rnn.history['val_loss'], label='RNN')
plt.plot(history_lstm.history['val_loss'], label='LSTM')
plt.plot(history_gru.history['val_loss'], label='GRU')

plt.title("Validation Loss Comparison")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.legend()
plt.show()
